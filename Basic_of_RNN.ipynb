# %% [markdown]
# <a href="https://colab.research.google.com/github/presentchris/NLP/blob/main/Basic_of_RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Step 1 - Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Dense, SimpleRNN
from tensorflow.keras.models import Sequential
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #Step 2 - Create Data

# %%
x = np.random.rand(100,10,1)
y = np.random.randint(0, 2, size = (100))

# %%
print("Shape of X is :", x.shape)
print("Shape of Y is :", y.shape)
# Out:
# Shape of X is : (100, 10, 1)
# Shape of Y is : (100,)

# %% [markdown]
# #Step 3 - Build The Model

# %%
model = Sequential([
    SimpleRNN(32, input_shape = (10, 1)),
    Dense(1, activation = "sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 32)                1088
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 1121 (4.38 KB)
# Trainable params: 1121 (4.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
history = model.fit(x, y, epochs = 10, validation_split =0.2, batch_size = 32, verbose = 1)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 1s 136ms/step - loss: 0.7056 - accuracy: 0.5000 - val_loss: 0.6918 - val_accuracy: 0.5000
# Epoch 2/10
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6897 - accuracy: 0.5250 - val_loss: 0.6796 - val_accuracy: 0.4500
# Epoch 3/10
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6847 - accuracy: 0.4750 - val_loss: 0.6751 - val_accuracy: 0.4500
# Epoch 4/10
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6829 - accuracy: 0.5375 - val_loss: 0.6715 - val_accuracy: 0.5500
# Epoch 5/10
# 3/3 [==============================] - 0s 15ms/step - loss: 0.6821 - accuracy: 0.5625 - val_loss: 0.6701 - val_accuracy: 0.5500
# Epoch 6/10
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6813 - accuracy: 0.5625 - val_loss: 0.6691 - val_accuracy: 0.6000
# Epoch 7/10
# ...

# %%
loss, accuracy = model.evaluate(x, y)

print("Accuracy of our model :", accuracy)
print("loss of our model :", loss)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6717 - accuracy: 0.5700
# Accuracy of our model : 0.5699999928474426
# loss of our model : 0.671688437461853

# %%
plt.figure(figsize = (10, 5))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label = 'accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy')
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,2)
plt.plot(history.history['loss'], label = 'loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss')
plt.show()
